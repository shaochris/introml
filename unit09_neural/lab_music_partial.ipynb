# %% [markdown]
# # Lab:  Neural Networks for Music Classification
#
# In addition to the concepts in the [MNIST neural network demo](./demo2_mnist_neural.ipynb), in this lab, you will learn to:
# * Load a file from a URL
# * Extract simple features from audio samples for machine learning tasks such as speech recognition and classification
# * Build a simple neural network for music classification using these features
# * Use a callback to store the loss and accuracy history in the training process
# * Optimize the learning rate of the neural network
#
# To illustrate the basic concepts, we will look at a relatively simple music classification problem.  Given a sample of music, we want to determine which instrument (e.g. trumpet, violin, piano) is playing.  This dataset was generously supplied by [Prof. Juan Bello](http://steinhardt.nyu.edu/faculty/Juan_Pablo_Bello) at NYU Stenihardt  and his former PhD student Eric Humphrey (now at Spotify).  They have a complete website dedicated to deep learning methods in music informatics:
#
# http://marl.smusic.nyu.edu/wordpress/projects/feature-learning-deep-architectures/deep-learning-python-tutorial/
#
# You can also check out Juan's <a href="http://www.nyu.edu/classes/bello/ACA.html">course</a>.

# %% [markdown]
# ## Loading Tensorflow
#
# Before starting this lab, you will need to install [Tensorflow](https://www.tensorflow.org/install/).  If you are using [Google colaboratory](https://colab.research.google.com), Tensorflow is already installed.  Run the following command to ensure Tensorflow is installed.

# %%
import tensorflow as tf

# %% [markdown]
# Then, load the other packages.

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# ## Audio Feature Extraction with Librosa
#
# The key to audio classification is to extract the correct features. In addition to `keras`, we will need the `librosa` package.  The `librosa` package in python has a rich set of methods extracting the features of audio samples commonly used in machine learning tasks such as speech recognition and sound classification.
#
# Installation instructions and complete documentation for the package are given on the [librosa main page](https://librosa.github.io/librosa/).  On most systems, you should be able to simply use:
#
#     pip install librosa
#
# For Unix, you may need to load some additional packages:
#
#     sudo apt-get install build-essential
#     sudo apt-get install libxext-dev python-qt4 qt4-dev-tools
#     pip install librosa
#
# After you have installed the package, try to import it.

# %%
import librosa
import librosa.display
import librosa.feature

# %% [markdown]
# In this lab, we will use a set of music samples from the website:
#
# http://theremin.music.uiowa.edu
#
# This website has a great set of samples for audio processing.  Look on the web for how to use the `requests.get` and `file.write` commands to load the file at the URL provided into your working directory.
#
# You can play the audio sample by copying the file to your local machine and playing it on any media player.  If you listen to it you will hear a soprano saxaphone (with vibrato) playing four notes (C, C#, D, Eb).

# %%
import requests
fn = "SopSax.Vib.pp.C6Eb6.aiff"
url = "http://theremin.music.uiowa.edu/sound files/MIS/Woodwinds/sopranosaxophone/"+fn

# TODO:  Load the file from url and save it in a file under the name fn
r = requests.get(url, allow_redirects=True)
open("SopSax.Vib.pp.C6Eb6.aiff", 'wb').write(r.content)
# Out:
# 1418242

# %% [markdown]
# Next, use `librosa` command `librosa.load` to read the audio file with filename `fn` and get the samples `y` and sample rate `sr`.

# %%
# TODO
# y, sr = ...
y, sr = librosa.load(fn)

# %% [markdown]
# Extracting features from audio files is an entire subject on its own right.  A commonly used set of features are called the Mel Frequency Cepstral Coefficients (MFCCs).  These are derived from the so-called mel spectrogram which is something like a regular spectrogram, but the power and frequency are represented in log scale, which more naturally aligns with human perceptual processing.  You can run the code below to display the mel spectrogram from the audio sample.
#
# You can easily see the four notes played in the audio track.  You also see the 'harmonics' of each notes, which are other tones at integer multiples of the fundamental frequency of each note.

# %%
S = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=128, fmax=8000)
librosa.display.specshow(librosa.amplitude_to_db(S),
                         y_axis='mel', fmax=8000, x_axis='time')
plt.colorbar(format='%+2.0f dB')

plt.title('Mel spectrogram')
plt.tight_layout()

# %% [markdown]
# ## Downloading the Data
#
# Using the MFCC features described above, Eric Humphrey and Juan Bellow have created a complete data set that can used for instrument classification.  Essentially, they collected a number of data files from the website above.  For each audio file, the segmented the track into notes and then extracted 120 MFCCs for each note.  The goal is to recognize the instrument from the 120 MFCCs.  The process of feature extraction is quite involved.  So, we will just use their processed data provided at:
#
# https://github.com/marl/dl4mir-tutorial/blob/master/README.md
#
# Note the password.  Load the four files into some directory, say  `instrument_dataset`.  Then, load them with the commands.

# %%
data_dir = 'instrument_dataset/'
Xtr = np.load(data_dir+'uiowa_train_data.npy')
ytr = np.load(data_dir+'uiowa_train_labels.npy')
Xts = np.load(data_dir+'uiowa_test_data.npy')
yts = np.load(data_dir+'uiowa_test_labels.npy')

# %% [markdown]
# Looking at the data files:
# * What are the number of training and test samples?
# * What is the number of features for each sample?
# * How many classes (i.e. instruments) are there per class?

# %%
# TODO
num_tr = Xtr.shape[0]
num_ts = Xts.shape[0]
num_fea = Xtr.shape[1]
num_class = np.max(ytr)+1

print("There are " + str(num_tr) + " training samples")
print("There are " + str(num_ts) + " test samples")
print("There are " + str(num_fea) + " of features each sample")
print("There are " + str(num_class) + " of classes per class")
# Out:
# There are 66247 training samples
# There are 14904 test samples
# There are 120 of features each sample
# There are 10 of classes per class

# %% [markdown]
# Before continuing, you must scale the training and test data, `Xtr` and `Xts`.  Compute the mean and std deviation of each feature in `Xtr` and create a new training data set, `Xtr_scale`, by subtracting the mean and dividing by the std deviation.  Also compute a scaled test data set, `Xts_scale` using the mean and std deviation learned from the training data set.

# %%
# TODO Scale the training and test matrices

# Xtr_scale = ...
# Xts_scale = ...

x_mean = np.mean(Xtr, axis=0)
x_std  = np.std(Xtr, axis=0)
Xtr_scale = (Xtr-x_mean[None, :]) / x_std[None, :]
Xts_scale = (Xts-x_mean[None, :]) / x_std[None, :]

# %% [markdown]
# ## Building a Neural Network Classifier
#
# Following the example in [MNIST neural network demo](./mnist_neural.ipynb), clear the keras session.  Then, create a neural network `model` with:
# * `nh=256` hidden units
# * `sigmoid` activation
# * select the input and output shapes correctly
# * print the model summary

# %%
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Dense, Activation
import tensorflow.keras.backend as K

# %%
# TODO clear session
K.clear_session()

# %%
# TODO: construct the model
nh=256
nin = Xtr.shape[1] # dimensions
nout = np.max(ytr) + 1
model = Sequential()
model.add(Dense(units=nh, input_shape=(nin,), activation='sigmoid', name='hidden'))
model.add(Dense(units=nout, activation='softmax', name='output'))

# %%
# TODO:  Print the model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# hidden (Dense)               (None, 256)               30976
# _________________________________________________________________
# output (Dense)               (None, 10)                2570
# =================================================================
# Total params: 33,546
# Trainable params: 33,546
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Create an optimizer and compile the model.  Select the appropriate loss function and metrics.  For the optimizer, use the Adam optimizer with a learning rate of 0.001

# %%
# TODO
# opt = ...
# model.compile(...)
from tensorflow.keras import optimizers

opt = optimizers.Adam(lr=0.001) 
model.compile(optimizer=opt,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# Fit the model for 10 epochs using the scaled data for both the training and validation.  Use the `validation_data` option to pass the test data.  Also, pass the callback class create above.  Use a batch size of 100.  Your final accuracy should be >99%.

# %%
# TODO
hist = model.fit(Xtr_scale, ytr, epochs=10, batch_size=100, validation_data=(Xts_scale,yts))
# Out:
# Epoch 1/10
# 663/663 [==============================] - 1s 1ms/step - loss: 0.3582 - accuracy: 0.9022 - val_loss: 0.1989 - val_accuracy: 0.9399
# Epoch 2/10
# 663/663 [==============================] - 1s 891us/step - loss: 0.1024 - accuracy: 0.9755 - val_loss: 0.0857 - val_accuracy: 0.9826
# Epoch 3/10
# 663/663 [==============================] - 1s 889us/step - loss: 0.0605 - accuracy: 0.9858 - val_loss: 0.0804 - val_accuracy: 0.9744
# Epoch 4/10
# 663/663 [==============================] - 1s 898us/step - loss: 0.0425 - accuracy: 0.9896 - val_loss: 0.0447 - val_accuracy: 0.9878
# Epoch 5/10
# 663/663 [==============================] - 1s 908us/step - loss: 0.0325 - accuracy: 0.9917 - val_loss: 0.0392 - val_accuracy: 0.9897
# Epoch 6/10
# 663/663 [==============================] - 1s 910us/step - loss: 0.0255 - accuracy: 0.9930 - val_loss: 0.0297 - val_accuracy: 0.9927
# Epoch 7/10
# 663/663 [==============================] - 1s 907us/step - loss: 0.0208 - accuracy: 0.9945 - val_loss: 0.0272 - val_accuracy: 0.9923
# Epoch 8/10
# 663/663 [==============================] - 1s 934us/step - loss: 0.0173 - accuracy: 0.9957 - val_loss: 0.0292 - val_accuracy: 0.9915
# Epoch 9/10
# 663/663 [==============================] - 1s 900us/step - loss: 0.0147 - accuracy: 0.9965 - val_loss: 0.0242 - val_accuracy: 0.9931
# Epoch 10/10
# 663/663 [==============================] - 1s 903us/step - loss: 0.0131 - accuracy: 0.9965 - val_loss: 0.0234 - val_accuracy: 0.9921

# %% [markdown]
# Plot the validation accuracy saved in `hist.history` dictionary. This gives one accuracy value per epoch.  You should see that the validation accuracy saturates at a little higher than 99%.  After that it "bounces around" due to the noise in the stochastic gradient descent.

# %%
# TODO
tr_accuracy = hist.history['accuracy']
val_accuracy = hist.history['val_accuracy']

plt.plot(tr_accuracy)
plt.plot(val_accuracy)
plt.grid()
plt.xlabel('epochs')
plt.ylabel('accuarcy')
plt.legend(['training accuracy', 'validation accuracy'])

# %% [markdown]
# Plot the loss values saved in the `hist.history` dictionary.  You should see that the loss is steadily decreasing.  Use the `semilogy` plot.

# %%
# TODO

nit = 10 # number of batches needed to complete on epoch

# Loss, accuracy and epoch per iteration
loss = hist.history['loss']
acc = hist.history['accuracy']
nepoch_per_it = num_tr // 100


epoch_it = np.arange(1,nit+1)*nepoch_per_it
plt.subplot(1,2,1)
plt.plot(epoch_it, loss)
plt.grid()
plt.xlabel('Epoch')
plt.ylabel('Loss')

plt.subplot(1,2,2)
plt.plot(epoch_it, acc)
plt.grid()
plt.xlabel('Epoch')
plt.ylabel('Training accuracy')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Optimizing the Learning Rate
#
# One challenge in training neural networks is the selection of the learning rate.  Rerun the above code, trying four learning rates as shown in the vector `rates`.  For each learning rate:
# * clear the session
# * construct the network
# * select the optimizer.  Use the Adam optimizer with the appropriate learrning rate.
# * train the model for 20 epochs
# * save the accuracy and losses

# %%
rates = [0.01,0.001,0.0001]
batch_size = 100
loss_hist = []
acc_hist = []
# TODO
# for lr in rate:
#    ...


for i, lr in enumerate(rates):
    # clear the session
    K.clear_session()
    # construct the network
    nh=256
    nin = Xtr.shape[1] # dimensions
    nout = np.max(ytr) + 1
    model = Sequential()
    model.add(Dense(units=nh, input_shape=(nin,), activation='sigmoid', name='hidden'))
    model.add(Dense(units=nout, activation='softmax', name='output'))
    # select optimizer
    opt = optimizers.Adam(lr=lr) 
    model.compile(optimizer=opt,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    # train
    nepoch = 20
    hist = model.fit(Xtr_scale, ytr, epochs=nepoch, batch_size=100, validation_data=(Xts_scale,yts))
    # save acc and loss
    loss_hist.append(hist.history['loss'])
    acc_hist.append(hist.history['accuracy'])
# Out:
# Epoch 1/20
# 663/663 [==============================] - 1s 1ms/step - loss: 0.1047 - accuracy: 0.9685 - val_loss: 0.0614 - val_accuracy: 0.9775
# Epoch 2/20
# 663/663 [==============================] - 1s 904us/step - loss: 0.0306 - accuracy: 0.9899 - val_loss: 0.0253 - val_accuracy: 0.9908
# Epoch 3/20
# 663/663 [==============================] - 1s 927us/step - loss: 0.0226 - accuracy: 0.9926 - val_loss: 0.0385 - val_accuracy: 0.9864
# Epoch 4/20
# 663/663 [==============================] - 1s 908us/step - loss: 0.0179 - accuracy: 0.9940 - val_loss: 0.0249 - val_accuracy: 0.9912
# Epoch 5/20
# 663/663 [==============================] - 1s 910us/step - loss: 0.0179 - accuracy: 0.9942 - val_loss: 0.0282 - val_accuracy: 0.9909
# Epoch 6/20
# 663/663 [==============================] - 1s 917us/step - loss: 0.0121 - accuracy: 0.9961 - val_loss: 0.0442 - val_accuracy: 0.9871
# Epoch 7/20
# 663/663 [==============================] - 1s 941us/step - loss: 0.0136 - accuracy: 0.9957 - val_loss: 0.0363 - val_accuracy: 0.9893
# Epoch 8/20
# 663/663 [==============================] - 1s 916us/step - loss: 0.0127 - accuracy: 0.9959 - val_loss: 0.0300 - val_accuracy: 0.9909
# Epoch 9/20
# 663/663 [==============================] - 1s 939us/step - loss: 0.0123 - accuracy: 0.9961 - val_loss: 0.0450 - val_accuracy: 0.9866
# Epoch 10/20
# 663/663 [==============================] - 1s 917us/step - loss: 0.0131 - accuracy: 0.9960 - val_loss: 0.0411 - val_accuracy: 0.9895
# Epoch 11/20
# 663/663 [==============================] - 1s 957us/step - loss: 0.0098 - accuracy: 0.9969 - val_loss: 0.0282 - val_accuracy: 0.9917
# Epoch 12/20
# 663/663 [==============================] - 1s 958us/step - loss: 0.0092 - accuracy: 0.9969 - val_loss: 0.0300 - val_accuracy: 0.9925
# Epoch 13/20
# 663/663 [==============================] - 1s 913us/step - loss: 0.0095 - accuracy: 0.9972 - val_loss: 0.0383 - val_accuracy: 0.9897
# Epoch 14/20
# 663/663 [==============================] - 1s 917us/step - loss: 0.0079 - accuracy: 0.9977 - val_loss: 0.0434 - val_accuracy: 0.9887
# Epoch 15/20
# 663/663 [==============================] - 1s 972us/step - loss: 0.0086 - accuracy: 0.9973 - val_loss: 0.0265 - val_accuracy: 0.9920
# Epoch 16/20
# 663/663 [==============================] - 1s 920us/step - loss: 0.0109 - accuracy: 0.9968 - val_loss: 0.0453 - val_accuracy: 0.9885
# Epoch 17/20
# 663/663 [==============================] - 1s 1ms/step - loss: 0.0112 - accuracy: 0.9965 - val_loss: 0.0994 - val_accuracy: 0.9830
# Epoch 18/20
# 663/663 [==============================] - 1s 1ms/step - loss: 0.0055 - accuracy: 0.9982 - val_loss: 0.1050 - val_accuracy: 0.9826
# Epoch 19/20
# 663/663 [==============================] - 1s 1ms/step - loss: 0.0080 - accuracy: 0.9977 - val_loss: 0.0592 - val_accuracy: 0.9891
# Epoch 20/20
# 663/663 [==============================] - 1s 1ms/step - loss: 0.0067 - accuracy: 0.9979 - val_loss: 0.0906 - val_accuracy: 0.9834
# Epoch 1/20
# 663/663 [==============================] - 1s 1ms/step - loss: 0.3643 - accuracy: 0.8990 - val_loss: 0.1952 - val_accuracy: 0.9390
# Epoch 2/20
# 663/663 [==============================] - 1s 1ms/step - loss: 0.1029 - accuracy: 0.9749 - val_loss: 0.1002 - val_accuracy: 0.9710
# Epoch 3/20
# 663/663 [==============================] - 1s 1ms/step - loss: 0.0605 - accuracy: 0.9856 - val_loss: 0.0582 - val_accuracy: 0.9871
# Epoch 4/20
# 663/663 [==============================] - 1s 1ms/step - loss: 0.0429 - accuracy: 0.9894 - val_loss: 0.0457 - val_accuracy: 0.9883
# Epoch 5/20
# 663/663 [==============================] - 1s 933us/step - loss: 0.0324 - accuracy: 0.9918 - val_loss: 0.0369 - val_accuracy: 0.9900
# Epoch 6/20
# 663/663 [==============================] - 1s 948us/step - loss: 0.0256 - accuracy: 0.9933 - val_loss: 0.0325 - val_accuracy: 0.9915
# Epoch 7/20
# 663/663 [==============================] - 1s 944us/step - loss: 0.0212 - accuracy: 0.9944 - val_loss: 0.0347 - val_accuracy: 0.9907
# Epoch 8/20
# 663/663 [==============================] - 1s 1ms/step - loss: 0.0177 - accuracy: 0.9953 - val_loss: 0.0284 - val_accuracy: 0.9912
# Epoch 9/20
# 663/663 [==============================] - 1s 1ms/step - loss: 0.0149 - accuracy: 0.9963 - val_loss: 0.0269 - val_accuracy: 0.9908
# Epoch 10/20
# 663/663 [==============================] - 1s 1ms/step - loss: 0.0129 - accuracy: 0.9968 - val_loss: 0.0247 - val_accuracy: 0.9919
# Epoch 11/20
# 663/663 [==============================] - 1s 1ms/step - loss: 0.0118 - accuracy: 0.9970 - val_loss: 0.0267 - val_accuracy: 0.9910
# Epoch 12/20
# 663/663 [==============================] - 1s 1ms/step - loss: 0.0101 - accuracy: 0.9973 - val_loss: 0.0228 - val_accuracy: 0.9917
# Epoch 13/20
# 663/663 [==============================] - 1s 1ms/step - loss: 0.0094 - accuracy: 0.9975 - val_loss: 0.0245 - val_accuracy: 0.9911
# Epoch 14/20
# 663/663 [==============================] - 1s 1ms/step - loss: 0.0084 - accuracy: 0.9978 - val_loss: 0.0223 - val_accuracy: 0.9919
# Epoch 15/20
# 663/663 [==============================] - 1s 1ms/step - loss: 0.0076 - accuracy: 0.9980 - val_loss: 0.0263 - val_accuracy: 0.9909
# Epoch 16/20
# 663/663 [==============================] - 1s 1ms/step - loss: 0.0071 - accuracy: 0.9981 - val_loss: 0.0260 - val_accuracy: 0.9902
# Epoch 17/20
# 663/663 [==============================] - 1s 1ms/step - loss: 0.0064 - accuracy: 0.9982 - val_loss: 0.0244 - val_accuracy: 0.9909
# Epoch 18/20
# 663/663 [==============================] - 1s 954us/step - loss: 0.0060 - accuracy: 0.9983 - val_loss: 0.0242 - val_accuracy: 0.9908
# Epoch 19/20
# 663/663 [==============================] - 1s 994us/step - loss: 0.0055 - accuracy: 0.9986 - val_loss: 0.0216 - val_accuracy: 0.9919
# Epoch 20/20
# 663/663 [==============================] - 1s 948us/step - loss: 0.0055 - accuracy: 0.9985 - val_loss: 0.0247 - val_accuracy: 0.9912
# Epoch 1/20
# 663/663 [==============================] - 1s 1ms/step - loss: 1.1007 - accuracy: 0.6567 - val_loss: 0.8261 - val_accuracy: 0.6830
# Epoch 2/20
# 663/663 [==============================] - 1s 982us/step - loss: 0.5331 - accuracy: 0.8585 - val_loss: 0.5519 - val_accuracy: 0.8313
# Epoch 3/20
# 663/663 [==============================] - 1s 1ms/step - loss: 0.3703 - accuracy: 0.9166 - val_loss: 0.4222 - val_accuracy: 0.8824
# Epoch 4/20
# 663/663 [==============================] - 1s 935us/step - loss: 0.2873 - accuracy: 0.9361 - val_loss: 0.3355 - val_accuracy: 0.9138
# Epoch 5/20
# 663/663 [==============================] - 1s 1ms/step - loss: 0.2344 - accuracy: 0.9478 - val_loss: 0.2818 - val_accuracy: 0.9235
# Epoch 6/20
# 663/663 [==============================] - 1s 913us/step - loss: 0.1966 - accuracy: 0.9555 - val_loss: 0.2310 - val_accuracy: 0.9406
# Epoch 7/20
# 663/663 [==============================] - 1s 921us/step - loss: 0.1676 - accuracy: 0.9612 - val_loss: 0.2049 - val_accuracy: 0.9431
# Epoch 8/20
# 663/663 [==============================] - 1s 991us/step - loss: 0.1446 - accuracy: 0.9658 - val_loss: 0.1750 - val_accuracy: 0.9517
# Epoch 9/20
# 663/663 [==============================] - 1s 957us/step - loss: 0.1261 - accuracy: 0.9698 - val_loss: 0.1567 - val_accuracy: 0.9550
# Epoch 10/20
# 663/663 [==============================] - 1s 954us/step - loss: 0.1110 - accuracy: 0.9736 - val_loss: 0.1355 - val_accuracy: 0.9619
# Epoch 11/20
# 663/663 [==============================] - 1s 939us/step - loss: 0.0987 - accuracy: 0.9765 - val_loss: 0.1262 - val_accuracy: 0.9618
# Epoch 12/20
# 663/663 [==============================] - 1s 941us/step - loss: 0.0885 - accuracy: 0.9793 - val_loss: 0.1062 - val_accuracy: 0.9749
# Epoch 13/20
# 663/663 [==============================] - 1s 956us/step - loss: 0.0800 - accuracy: 0.9814 - val_loss: 0.0983 - val_accuracy: 0.9747
# Epoch 14/20
# 663/663 [==============================] - 1s 933us/step - loss: 0.0729 - accuracy: 0.9832 - val_loss: 0.0915 - val_accuracy: 0.9769
# Epoch 15/20
# 663/663 [==============================] - 1s 937us/step - loss: 0.0669 - accuracy: 0.9842 - val_loss: 0.0811 - val_accuracy: 0.9797
# Epoch 16/20
# 663/663 [==============================] - 1s 944us/step - loss: 0.0616 - accuracy: 0.9855 - val_loss: 0.0747 - val_accuracy: 0.9830
# Epoch 17/20
# 663/663 [==============================] - 1s 949us/step - loss: 0.0573 - accuracy: 0.9863 - val_loss: 0.0704 - val_accuracy: 0.9832
# Epoch 18/20
# 663/663 [==============================] - 1s 991us/step - loss: 0.0534 - accuracy: 0.9871 - val_loss: 0.0683 - val_accuracy: 0.9852
# Epoch 19/20
# 663/663 [==============================] - 1s 949us/step - loss: 0.0499 - accuracy: 0.9878 - val_loss: 0.0637 - val_accuracy: 0.9850
# Epoch 20/20
# 663/663 [==============================] - 1s 934us/step - loss: 0.0470 - accuracy: 0.9886 - val_loss: 0.0616 - val_accuracy: 0.9852

# %% [markdown]
# Plot the loss funciton vs. the epoch number for all three learning rates on one graph.  You should see that the lower learning rates are more stable, but converge slower.

# %%
# TODO
nit = 20
nepoch_per_it = num_tr // 100
epoch_it = np.arange(1,nit+1)*nepoch_per_it

for loss in loss_hist:
    plt.plot(epoch_it, loss)
    plt.grid()
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
plt.legend(['lr=0.0001', 'lr=0.001', 'lr=0.01'])
plt.show()
